# %% [markdown]
# # 01 :- Write a Python program to check if a number is positive, negative or zero

# %%
num = int(input("ENTER A NUMBER:"))

if num > 0:
    print(num,"is a positive")
   
elif num == 0:
    print(num,"is a zero")
    
else:
    print(num,"is a negative")
# Out:
# ENTER A NUMBER:5
# 5 is a positive

# %% [markdown]
# #02 :- Write a Python program to get the Fibonacci series of given range.

# %%
n=int(input("ENTER NUMBER : "))

x=0
y=1
z=0

while (z<=n):
    print(z)
    
    x=y
    y=z
    z=x+y
# Out:
# ENTER NUMBER : 22
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %% [markdown]
# #03 :- How memory is managed in Python?
# ANSWER :- Memory management in Python involves a private heap containing all Python objects and data structures. The management of this private heap is ensured internally by the Python memory manager. The Python memory manager has different components which deal with various dynamic storage management aspects, like sharing, segmentation, preallocation or caching.

# %%
#04 :- What is the purpose continue statement in python?
#Definition = The continue keyword is used to end the current iteration in a for loop (or a while loop), and continues to the next iteration.
i = 0
while i < 9:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# 05 :- Write python program that swap two number with temp variable and
# without temp variable.

# %%
a=10
b=22

print("A = ",a,"AND B = ",b)

a=a+b    #10+22=32
b=a-b    #32-22=10  (VALUE OF B)
a=a-b    #32-10=22  (VALUE OF A)

print("A = ",a,"AND B = ",b)
# Out:
# A =  10 AND B =  22
# A =  22 AND B =  10

# %% [markdown]
# 06 :- Write a Python program to find whether a given number is even or odd,
# print out an appropriate message to the user.

# %%
number = int(input("ENTER AN INTEGER NUMBER : "))
remainder = number % 2

if (remainder == 0):
    print(number," IS AN EVEN NUMBER")
  
else:
    print(number," IS AND ODD NUMBER")
# Out:
# ENTER AN INTEGER NUMBER : 12
# 12  IS AN EVEN NUMBER

# %% [markdown]
# 07 :- Write a Python program to test whether a passed letter is a vowel or not

# %%
x = input("ENTER A SENTENCE: ")

count = 0

for i in x :
 if i.lower()=='a' or i.lower()=='e' or i.lower()=='i' or i.lower()=="o" or i.lower()=='u':
  print(i)
   count = count+1

 if count == 0 :
   print("NO VOWEL FOUND")
    
 else:
    print("NUMBER OF VOWELS: ",count)

# %% [markdown]
# Write a Python program to check if a number is positive, negative or zero

# %%
num = int(input("ENTER A NUMBER:"))

if num > 0:
    print(num,"is a positive")
   
elif num == 0:
    print(num,"is a zero")
    
else:
    print(num,"is a negative")
# Out:
# ENTER A NUMBER:-22
# -22 is a negative
